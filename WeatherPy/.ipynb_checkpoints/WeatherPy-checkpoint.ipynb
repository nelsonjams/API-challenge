# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=6cd4f8e53c48d71ff28cda802538e56a&units=metric&q=

# %%
response = requests.get(query_url+"London")
#print(response.json())
weather=response.json()
#weather["main"]["temp"]
weather
# Out:
# {'coord': {'lon': -0.13, 'lat': 51.51},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 2.11,
#   'pressure': 1024,
#   'humidity': 100,
#   'temp_min': -1.11,
#   'temp_max': 5.56},
#  'visibility': 10000,
#  'wind': {'speed': 1, 'deg': 200},
#  'clouds': {'all': 0},
#  'dt': 1575410859,
#  'sys': {'type': 1,
#   'id': 1502,
#   'country': 'GB',
#   'sunrise': 1575359176,
#   'sunset': 1575388468},
#  'timezone': 0,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
data=[]
i=0
for city in cities:
    i=i+1
    response = requests.get(query_url+city).json()
    try:
        temperature=response["main"]["temp_max"]
        humidity=response["main"]["humidity"]
        speed=response["wind"]["speed"]
        cloudiness=response["clouds"]["all"]
        latitude=response["coord"]["lat"]
        longitude=response["coord"]["lon"]
        date=response["dt"]
        country=response["sys"]["country"]
        data.append([temperature, humidity, speed, cloudiness, latitude, longitude, date, country])
        print(f"counter {i} || {city}")    
        time.sleep(.1)
    except:
        print("city not found")
# Out:
# counter 1 || san policarpo
# counter 2 || ancud
# counter 3 || busselton
# counter 4 || waipawa
# counter 5 || punta arenas
# city not found
# counter 7 || fereydun kenar
# counter 8 || zhangjiakou
# counter 9 || searcy
# counter 10 || san andres
# counter 11 || praia
# counter 12 || saint-georges
# counter 13 || ilulissat
# counter 14 || polunochnoye
# counter 15 || sur
# counter 16 || clarence town
# counter 17 || santa ana
# counter 18 || bethel
# counter 19 || vestmannaeyjar
# counter 20 || bluff
# counter 21 || zonguldak
# counter 22 || ushuaia
# counter 23 || mataura
# counter 24 || longyearbyen
# counter 25 || buin
# counter 26 || washougal
# counter 27 || albany
# counter 28 || puerto leguizamo
# counter 29 || talnakh
# counter 30 || moose factory
# counter 31 || sabang
# counter 32 || bredasdorp
# counter 33 || bambous virieux
# counter 34 || kapaa
# counter 35 || hille
# counter 36 || hilo
# counter 37 || mill valley
# counter 38 || severo-kurilsk
# counter 39 || raymondville
# counter 40 || port alfred
# counter 41 || lagoa
# counter 42 || kidal
# counter 43 || ahuimanu
# counter 44 || mahebourg
# counter 45 || arona
# counter 46 || belmonte
# counter 47 || cassilandia
# counter 48 || castro
# counter 49 || iwaki
# counter 50 || hohhot
# city not found
# counter 52 || dikson
# counter 53 || san felipe
# counter 54 || arraial do cabo
# counter 55 || egvekinot
# counter 56 || xinzhou
# counter 57 || necochea
# counter 58 || mitu
# counter 59 || yellowknife
# counter 60 || adet
# counter 61 || portland
# counter 62 || bramming
# counter 63 || hithadhoo
# counter 64 || teno
# counter 65 || atuona
# counter 66 || westport
# counter 67 || rikitea
# city not found
# counter 69 || san juan
# counter 70 || georgetown
# counter 71 || ialibu
# counter 72 || sinnamary
# counter 73 || thompson
# counter 74 || saskylakh
# counter 75 || katsuura
# city not found
# city not found
# counter 78 || thohoyandou
# counter 79 || east london
# counter 80 || jamestown
# counter 81 || victoria
# counter 82 || rio gallegos
# counter 83 || hobart
# counter 84 || nikolskoye
# counter 85 || sibutad
# counter 86 || saldanha
# counter 87 || hasaki
# counter 88 || komsomolskiy
# counter 89 || aksarka
# counter 90 || fortuna
# counter 91 || pangnirtung
# counter 92 || cherskiy
# counter 93 || kaitangata
# counter 94 || vestmanna
# counter 95 || san patricio
# counter 96 || taixing
# counter 97 || avarua
# counter 98 || champerico
# counter 99 || dunedin
# counter 100 || yeppoon
# counter 101 || ust-nera
# counter 102 || praya
# counter 103 || ojinaga
# counter 104 || hermanus
# counter 105 || mehamn
# counter 106 || butaritari
# counter 107 || lenoir city
# counter 108 || tuktoyaktuk
# city not found
# counter 110 || geraldton
# counter 111 || tuatapere
# city not found
# counter 113 || huntsville
# city not found
# counter 115 || tasiilaq
# counter 116 || umba
# counter 117 || fuji
# counter 118 || vila franca do campo
# counter 119 || new norfolk
# counter 120 || strezhevoy
# counter 121 || batagay
# counter 122 || qaqortoq
# counter 123 || chuy
# counter 124 || torbay
# counter 125 || khatanga
# counter 126 || kamaishi
# counter 127 || staryy nadym
# counter 128 || cairns
# counter 129 || pitimbu
# counter 130 || divnomorskoye
# counter 131 || amuntai
# city not found
# counter 133 || cidreira
# counter 134 || mogadishu
# counter 135 || saint george
# counter 136 || buraydah
# counter 137 || kavieng
# city not found
# counter 139 || callaway
# counter 140 || neuquen
# counter 141 || charleston
# counter 142 || codrington
# counter 143 || narsaq
# counter 144 || provideniya
# counter 145 || norman wells
# counter 146 || vaini
# counter 147 || namibe
# counter 148 || lebu
# counter 149 || los llanos de aridane
# counter 150 || port elizabeth
# counter 151 || caravelas
# counter 152 || denpasar
# counter 153 || bilibino
# counter 154 || kodiak
# counter 155 || mata
# counter 156 || smithers
# counter 157 || hirara
# counter 158 || tavda
# counter 159 || homer
# counter 160 || mali
# counter 161 || pevek
# city not found
# counter 163 || santa fe
# city not found
# counter 165 || sao gotardo
# counter 166 || upernavik
# counter 167 || cayenne
# counter 168 || riyadh
# counter 169 || lewisporte
# counter 170 || esperance
# counter 171 || baryatino
# counter 172 || djenne
# city not found
# counter 174 || vardo
# counter 175 || pecos
# counter 176 || yarada
# counter 177 || jeronimo monteiro
# counter 178 || bud
# counter 179 || wahpeton
# counter 180 || hare bay
# counter 181 || antalaha
# counter 182 || sosva
# counter 183 || ken caryl
# counter 184 || cape town
# counter 185 || ullapool
# counter 186 || carnarvon
# counter 187 || rawson
# counter 188 || atbasar
# city not found
# counter 190 || taos
# counter 191 || barrow
# counter 192 || south lake tahoe
# counter 193 || berlevag
# counter 194 || tautira
# city not found
# city not found
# counter 197 || ayan
# counter 198 || marsh harbour
# counter 199 || leningradskiy
# counter 200 || mar del plata
# counter 201 || puerto ayora
# counter 202 || batagay-alyta
# counter 203 || presidencia roque saenz pena
# counter 204 || mumbwa
# counter 205 || baykit
# counter 206 || hopfgarten
# counter 207 || tiksi
# city not found
# counter 209 || gobabis
# counter 210 || ilheus
# counter 211 || ribeira grande
# counter 212 || chokurdakh
# counter 213 || te anau
# counter 214 || price
# counter 215 || sao filipe
# counter 216 || hualmay
# counter 217 || saryozek
# counter 218 || teguise
# counter 219 || ponta do sol
# counter 220 || kihei
# counter 221 || grindavik
# counter 222 || cockburn town
# counter 223 || atikokan
# counter 224 || tessalit
# counter 225 || vaitape
# counter 226 || batemans bay
# counter 227 || saint-philippe
# city not found
# counter 229 || faanui
# counter 230 || lavrentiya
# counter 231 || luderitz
# city not found
# counter 233 || isangel
# counter 234 || auki
# counter 235 || garoua
# city not found
# counter 237 || aranos
# counter 238 || pulaski
# counter 239 || petrolina
# counter 240 || lompoc
# counter 241 || nizwa
# counter 242 || qasigiannguit
# counter 243 || qaanaaq
# counter 244 || durango
# city not found
# counter 246 || alofi
# counter 247 || borovoy
# counter 248 || iqaluit
# counter 249 || toamasina
# counter 250 || teya
# counter 251 || srednekolymsk
# counter 252 || san carlos de bariloche
# city not found
# counter 254 || pabrade
# counter 255 || kisanga
# counter 256 || hearst
# counter 257 || nassjo
# counter 258 || sharjah
# city not found
# counter 260 || tuy hoa
# counter 261 || touros
# city not found
# counter 263 || bowen
# counter 264 || manokwari
# counter 265 || vanimo
# counter 266 || newton
# counter 267 || hofn
# counter 268 || mount gambier
# counter 269 || yangjiang
# counter 270 || avera
# counter 271 || santa isabel do rio negro
# counter 272 || ulladulla
# counter 273 || aswan
# counter 274 || beian
# counter 275 || kaeo
# counter 276 || ixtapa
# city not found
# counter 278 || kruisfontein
# counter 279 || nata
# counter 280 || guaruja
# counter 281 || sakaiminato
# counter 282 || pangai
# counter 283 || beloha
# counter 284 || san carlos
# counter 285 || lianzhou
# counter 286 || koumac
# counter 287 || dingle
# counter 288 || sencha
# counter 289 || verkhnyaya sinyachikha
# counter 290 || quelimane
# counter 291 || jaisalmer
# counter 292 || turukhansk
# counter 293 || airai
# counter 294 || richards bay
# counter 295 || ahipara
# counter 296 || moultrie
# counter 297 || suntar
# counter 298 || waingapu
# counter 299 || buala
# counter 300 || lamu
# city not found
# counter 302 || poso
# counter 303 || porto novo
# counter 304 || mount isa
# counter 305 || conakry
# city not found
# counter 307 || broome
# counter 308 || kearney
# counter 309 || matai
# city not found
# counter 311 || high level
# counter 312 || huaraz
# counter 313 || arteaga
# counter 314 || sivaki
# counter 315 || oksfjord
# counter 316 || kahama
# counter 317 || kalanguy
# counter 318 || tura
# counter 319 || najran
# counter 320 || monrovia
# counter 321 || concordia
# city not found
# counter 323 || antigonish
# counter 324 || collie
# counter 325 || kuryk
# city not found
# counter 327 || dicabisagan
# counter 328 || pilar
# counter 329 || erdenet
# city not found
# city not found
# counter 332 || sao gabriel da cachoeira
# counter 333 || rameshki
# counter 334 || haines junction
# counter 335 || sola
# counter 336 || balkhash
# counter 337 || agua blanca
# counter 338 || kahului
# counter 339 || talcahuano
# counter 340 || baherden
# counter 341 || umm lajj
# city not found
# counter 343 || waverly
# counter 344 || college
# counter 345 || flinders
# counter 346 || kayerkan
# counter 347 || collingwood
# counter 348 || nome
# counter 349 || arrifes
# counter 350 || guozhen
# city not found
# counter 352 || bosaso
# counter 353 || vila
# counter 354 || chapais
# counter 355 || davila
# counter 356 || wenchi
# city not found
# counter 358 || hovd
# counter 359 || gualeguaychu
# city not found
# counter 361 || laramie
# counter 362 || huilong
# counter 363 || kizilskoye
# counter 364 || mgandu
# counter 365 || matata
# counter 366 || wheeling
# counter 367 || naze
# counter 368 || caledon
# counter 369 || hambantota
# counter 370 || tommot
# city not found
# counter 372 || hargeysa
# counter 373 || tecolutla
# counter 374 || hukay
# counter 375 || marsa matruh
# counter 376 || kloulklubed
# counter 377 || nampa
# counter 378 || mecca
# counter 379 || zalantun
# counter 380 || moron
# counter 381 || mackay
# counter 382 || sao francisco
# counter 383 || panalingaan
# counter 384 || sambava
# counter 385 || juegang
# counter 386 || nur
# counter 387 || fort wellington
# counter 388 || hammerfest
# counter 389 || thongwa
# counter 390 || cabo san lucas
# counter 391 || nago
# counter 392 || heishan
# counter 393 || hamilton
# counter 394 || guiratinga
# counter 395 || ebolowa
# counter 396 || sept-iles
# counter 397 || tankhoy
# counter 398 || san luis
# counter 399 || faya
# counter 400 || dreux
# counter 401 || nishihara
# counter 402 || mount darwin
# counter 403 || saint-augustin
# counter 404 || bathsheba
# counter 405 || south valley
# counter 406 || isetskoye
# city not found
# counter 408 || pisco
# counter 409 || freeport
# city not found
# counter 411 || malanje
# counter 412 || solnechnyy
# counter 413 || yenagoa
# counter 414 || lasa
# city not found
# counter 416 || jiangyou
# counter 417 || karpinsk
# counter 418 || mahajanga
# counter 419 || nemuro
# city not found
# counter 421 || waiuku
# counter 422 || clacton-on-sea
# counter 423 || baijiantan
# counter 424 || bela vista do paraiso
# city not found
# city not found
# counter 427 || wanning
# counter 428 || aklavik
# city not found
# counter 430 || guerrero negro
# city not found
# city not found
# counter 433 || baraboo
# counter 434 || laguna de perlas
# counter 435 || makakilo city
# counter 436 || guatire
# counter 437 || colac
# counter 438 || canyon
# counter 439 || inhambane
# counter 440 || souillac
# counter 441 || belyy yar
# counter 442 || savona
# counter 443 || kenai
# counter 444 || murray bridge
# counter 445 || maragogi
# counter 446 || la ronge
# counter 447 || nosy varika
# counter 448 || nigde
# city not found
# counter 450 || vila velha
# counter 451 || darhan
# counter 452 || samarai
# counter 453 || kaihua
# counter 454 || clinton
# counter 455 || fort nelson
# counter 456 || saschiz
# counter 457 || trinidad
# counter 458 || falam
# counter 459 || quatre cocos
# city not found
# counter 461 || puerto del rosario
# city not found
# counter 463 || kikwit
# counter 464 || horodyshche
# counter 465 || verkhnyaya inta
# counter 466 || beyneu
# city not found
# counter 468 || masuguru
# counter 469 || chake chake
# counter 470 || manturovo
# counter 471 || nadigaon
# counter 472 || camocim
# counter 473 || limbang
# counter 474 || bolgatanga
# counter 475 || montrose
# counter 476 || yatou
# counter 477 || nanortalik
# counter 478 || dongargaon
# counter 479 || seredka
# counter 480 || bad sachsa
# counter 481 || obera
# counter 482 || clyde river
# counter 483 || beberibe
# counter 484 || biala podlaska
# counter 485 || buchanan
# counter 486 || tianpeng
# counter 487 || ocosingo
# counter 488 || port lincoln
# counter 489 || palmer
# counter 490 || ada
# city not found
# counter 492 || ekhabi
# city not found
# counter 494 || vao
# counter 495 || anadyr
# counter 496 || narok
# counter 497 || codajas
# counter 498 || kemi
# city not found
# counter 500 || kehl
# counter 501 || victor harbor
# city not found
# counter 503 || menomonie
# counter 504 || morros
# counter 505 || temiscaming
# counter 506 || pangkalanbuun
# counter 507 || sangar
# counter 508 || sorong
# counter 509 || todos santos
# counter 510 || camopi
# counter 511 || asuncion nochixtlan
# counter 512 || limbe
# counter 513 || van
# counter 514 || hay river
# counter 515 || west richland
# counter 516 || grua
# counter 517 || gamba
# city not found
# counter 519 || sorland
# counter 520 || hvide sande
# counter 521 || kastamonu
# counter 522 || mongoumba
# counter 523 || dauriya
# counter 524 || lata
# counter 525 || laviana
# counter 526 || comodoro rivadavia
# counter 527 || neiafu
# counter 528 || camaqua
# counter 529 || kupang
# city not found
# counter 531 || linxia
# counter 532 || vigrestad
# counter 533 || krasnyy chikoy
# counter 534 || loa janan
# counter 535 || palora
# counter 536 || marsta
# city not found
# counter 538 || pimentel
# counter 539 || namatanai
# counter 540 || hollins
# counter 541 || merauke
# counter 542 || cam ranh
# counter 543 || alpignano
# counter 544 || dzhebariki-khaya
# city not found
# counter 546 || road town
# counter 547 || trairi
# counter 548 || itoman
# city not found
# city not found
# counter 551 || bodden town
# city not found
# counter 553 || pochutla
# counter 554 || terre-de-bas
# counter 555 || gberia fotombu
# counter 556 || mehran
# counter 557 || shingu
# counter 558 || havre-saint-pierre
# counter 559 || matamoros
# counter 560 || ossora
# counter 561 || nouadhibou
# counter 562 || fairbanks
# counter 563 || shelburne
# counter 564 || conceicao da barra
# city not found
# counter 566 || san joaquin
# counter 567 || kiruna
# counter 568 || dera bugti
# counter 569 || ostersund
# counter 570 || soe
# counter 571 || mount pleasant
# counter 572 || jijiga
# counter 573 || nouakchott
# counter 574 || paita
# city not found
# counter 576 || mangrol
# city not found
# counter 578 || culebra
# counter 579 || laem sing
# counter 580 || beboto
# counter 581 || ruteng
# counter 582 || kungurtug
# counter 583 || nchelenge
# counter 584 || aykhal
# counter 585 || reconquista
# counter 586 || batarci
# city not found
# counter 588 || port hueneme
# counter 589 || killybegs
# counter 590 || kaputa
# city not found
# counter 592 || chengdu
# counter 593 || springdale
# counter 594 || phalombe
# counter 595 || manaure
# counter 596 || kautokeino
# city not found
# counter 598 || omboue
# counter 599 || nieuw amsterdam
# counter 600 || grand-santi
# counter 601 || payo
# counter 602 || sobolevo
# counter 603 || ambilobe
# counter 604 || tignere
# counter 605 || kurya
# counter 606 || salalah
# counter 607 || marawi
# counter 608 || sao miguel do araguaia
# counter 609 || rodrigues alves
# counter 610 || tiszadob
# counter 611 || rio hondo
# counter 612 || sivas
# counter 613 || deputatskiy
# counter 614 || maumere
# counter 615 || chikhli
# counter 616 || dharchula
# counter 617 || sochi
# counter 618 || santa maria
# counter 619 || morondava
# counter 620 || tucuman
# counter 621 || klaksvik

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data_df=pd.DataFrame(data, columns=['Temperature', 'Humidity', 'Wind Speed', 'Cloudiness', 'Latitude', 'Longitude', 'Date',
                                    'Country'])
data_df.head(20)
# Out:
#     Temperature  Humidity  Wind Speed  Cloudiness  Latitude  Longitude  \
# 0         27.27        85        4.20          20     12.18     125.51
# 1         15.00        58        5.70          90    -41.87     -73.83
# 2         21.67        36        3.27          73    -33.64     115.35
# 3         21.17        40        1.73           0    -39.94     176.59
# 4         14.00        47       11.30          40    -53.16     -70.91
# 5          9.00       100        2.10          75     36.69      52.52
# 6         -9.99        75        2.57           0     40.77     114.88
# 7         14.44        43        3.60           1     35.25     -91.74
# 8         23.93        95        1.31         100     13.32     122.68
# 9         23.00        83        6.20          75    -20.25     -43.81
# 10        -3.89        81        0.45         100     46.12     -70.67
# 11       -12.00        55        9.30          20     69.22     -51.10
# 12       -10.38        92        2.22         100     60.87      60.43
# 13        21.87        63        2.78          44     22.57      59.53
# 14        24.00        29        7.70           0    -32.59     151.78
# 15        18.33        66        0.89          76     30.54    -111.12
# 16       -13.00        91        3.10           1     60.79    -161.76
# 17         4.79        85       13.38         100     63.44     -20.27
# 18        26.87        19        5.46           0    -23.58     149.07
# 19         3.15        79        0.48         100     41.25      31.83
#
#           Date Country
# 0   1575411076      PH
# 1   1575411076      CL
# 2   1575411076      AU
# 3   1575411077      NZ
# 4   1575411077      CL
# 5   1575411077      IR
# 6   1575411077      CN
# 7   1575411077      US
# 8   1575411077      PH
# 9   1575411077      BR
# 10  1575410781      CA
# 11  1575411078      GL
# 12  1575411078      RU
# 13  1575411078      OM
# 14  1575411078      AU
# 15  1575411078      MX
# 16  1575411078      US
# 17  1575411079      IS
# 18  1575411079      AU
# 19  1575411079      TR

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(data_df["Latitude"],data_df["Temperature"], c="cyan", edgecolor="black")
plt.title("Latitude vs. Temperature", fontsize=18)
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.grid(linestyle="dotted")
# Save the Figure
plt.savefig("LatvsTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(data_df["Latitude"],data_df["Humidity"], c="yellow", edgecolor="black")
plt.title("Latitude vs. Humidity", fontsize=18)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(linestyle="dotted")
#Save the Fig
plt.savefig("LatvsHumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(data_df["Latitude"],data_df["Cloudiness"], c="hotpink", edgecolor="black")
plt.title("Latitude vs. Cloudiness", fontsize=18)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(linestyle="dotted")
#Save the Fig
plt.savefig("LatvsCloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(data_df["Latitude"],data_df["Wind Speed"], c="lime", edgecolor="black")
plt.title("Latitude vs. Wind Speed", fontsize=18)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(linestyle="dotted")
#Save the Fig
plt.savefig("LatvsWindSpeed.png")
